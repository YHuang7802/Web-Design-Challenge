# %%
import pandas as pd

weather_data = pd.read_csv("Resources/export_weather_df.csv")

weather_data
# Out:
#      Unnamed: 0          City      Lat       Lng  Max Temp  Humidity  \
# 0             0      luderitz -26.6481   15.1594     67.32        41
# 1             1         kapaa  22.0752 -159.3190     78.78        89
# 2             2     saskylakh  71.9167  114.0833     -2.56        98
# 3             3    vila velha -20.3297  -40.2925     82.35        86
# 4             4      pasighat  28.0667   95.3333     69.12        72
# ..          ...           ...      ...       ...       ...       ...
# 553         553  tres arroyos -38.3739  -60.2798     67.55        83
# 554         554          vinh  18.6667  105.6667     78.40        88
# 555         555         paris  48.8534    2.3488     56.10        63
# 556         556      zyryanka  65.7500  150.8500     16.84        94
# 557         557        vanimo  -2.6741  141.3028     77.88        90
#
#      Cloudiness  Wind Speed Country        Date
# 0             0        9.19     NaN  1651004206
# ...

# %%
weather_data_rename= weather_data.rename(columns= {"Unnamed: 0":"city_id"})

weather_data_index = weather_data_rename.reset_index(drop = True)

weather_data_index
# Out:
#      city_id          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          0      luderitz -26.6481   15.1594     67.32        41           0
# 1          1         kapaa  22.0752 -159.3190     78.78        89         100
# 2          2     saskylakh  71.9167  114.0833     -2.56        98          99
# 3          3    vila velha -20.3297  -40.2925     82.35        86          40
# 4          4      pasighat  28.0667   95.3333     69.12        72          34
# ..       ...           ...      ...       ...       ...       ...         ...
# 553      553  tres arroyos -38.3739  -60.2798     67.55        83          89
# 554      554          vinh  18.6667  105.6667     78.40        88          37
# 555      555         paris  48.8534    2.3488     56.10        63          75
# 556      556      zyryanka  65.7500  150.8500     16.84        94         100
# 557      557        vanimo  -2.6741  141.3028     77.88        90         100
#
# ...

# %%
print(weather_data_index.to_html(index= False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>city_id</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>luderitz</td>
#       <td>-26.6481</td>
#       <td>15.1594</td>
#       <td>67.32</td>
#       <td>41</td>
#       <td>0</td>
#       <td>9.19</td>
#       <td>NaN</td>
#       <td>1651004206</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>kapaa</td>
#       <td>22.0752</td>
#       <td>-159.3190</td>
#       <td>78.78</td>
#       <td>89</td>
#       <td>100</td>
#       <td>14.97</td>
#       <td>US</td>
#       <td>1651004207</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>saskylakh</td>
#       <td>71.9167</td>
#       <td>114.0833</td>
# ...
